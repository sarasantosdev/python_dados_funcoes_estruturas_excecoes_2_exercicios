# %% [markdown]
# <a href="https://colab.research.google.com/github/sarasantosdev/python_dados_funcoes_estruturas_excecoes_2_exercicios/blob/main/python_dados_funcoes_estruturas_excecoes_2_exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funções - Exercícios

# %% [markdown]
# Você foi contratado(a) como cientista de dados de uma associação de skate. Para analisar as notas recebidas de skatistas em algumas competições ao longo do ano, você precisa criar um código que calcula a pontuação dos(as) atletas. Para isso, o seu código deve receber 5 notas digitadas pelas pessoas juradas.
#
# Para calcular a pontuação de um(a) skatista, você precisa eliminar a maior e a menor pontuação dentre as 5 notas e tirar a média das 3 notas que sobraram.

# %%
# minha solução
def media():
  notas = []
  for x in range(1,6):
    nota = float(input('Informe a nota do(a) atleta: '))
    notas.append(nota)

  notas.remove(max(notas))
  notas.remove(min(notas))

  media = sum(notas) / len(notas)

  return media

media()
# Out:
# Informe a nota do(a) atleta: 8
# Informe a nota do(a) atleta: 5
# Informe a nota do(a) atleta: 6
# Informe a nota do(a) atleta: 2
# Informe a nota do(a) atleta: 7
# 6.0

# %%
# solução do professor:
notas = []

for x in range(1,6):
  nota = float(input('Informe a nota do(a) atleta: '))
  notas.append(nota)

def media(notas):

  notas.remove(max(notas))
  notas.remove(min(notas))

  return sum(notas) / len(notas)

media(notas)
# Out:
# Informe a nota do(a) atleta: 8
# Informe a nota do(a) atleta: 5
# Informe a nota do(a) atleta: 6
# Informe a nota do(a) atleta: 2
# Informe a nota do(a) atleta: 7
# 6.0

# %%
# minha solução
nomes = ["joão", "MaRia", "JOSÉ"]
nomes_corrigidos = list(map(lambda x: x.capitalize(), nomes))
nomes_corrigidos

sobrenomes = ["SILVA", "souza", "Tavares"]
sobrenomes_corrigidos = list(map(lambda x: x.capitalize(), sobrenomes))
sobrenomes_corrigidos

for nome, sobrenome in zip(nomes_corrigidos, sobrenomes_corrigidos):
  print(f"Nome completo {nome} {sobrenome}")
# Out:
# Nome completo João Silva
# Nome completo Maria Souza
# Nome completo José Tavares

# %%
# uma das soluções do gemini
def formatar_nomes(lista):
  return [x.capitalize() for x in lista]

nomes = formatar_nomes(nomes)
sobrenomes = formatar_nomes(sobrenomes)

for nome, sobrenome in zip(nomes, sobrenomes):
  print(f"Nome completo: {nome} {sobrenome}")
# Out:
# Nome completo: João Silva
# Nome completo: Maria Souza
# Nome completo: José Tavares

# %%
# outra solução do gemini
nomes = ["joão", "MaRia", "JOSÉ"]
sobrenomes = ["SILVA", "souza", "Tavares"]

for nome, sobrenome in zip(nomes, sobrenomes):
  print(f"Nome completo: {nome.capitalize()} {sobrenome.capitalize()}")
# Out:
# Nome completo: João Silva
# Nome completo: Maria Souza
# Nome completo: José Tavares

# %%
# solução do professor:

nomes = ["joão", "MaRia", "JOSÉ"]
sobrenomes = ["SILVA", "souza", "Tavares"]

nome_completo = map(lambda nome, sobrenome: f'{nome.title()} {sobrenome.title()}', nomes, sobrenomes)

for n in nome_completo:
  print(f'Nome completo: {n}')
# Out:
# Nome completo: João Silva
# Nome completo: Maria Souza
# Nome completo: José Tavares

# %% [markdown]
# Como cientista de dados em um time de futebol, você precisa implementar novas formas de coleta de dados sobre o desempenho de jogadores e do time como um todo. Sua primeira ação é criar uma forma de calcular a pontuação do time no campeonato nacional a partir dos dados de gols marcados e sofridos em cada jogo.
#
# Escreva uma função chamada calcula_pontos que recebe como parâmetros duas listas de números inteiros, representando os gols marcados e sofridos pelo time em cada partida do campeonato. A função deve retornar a pontuação do time e o aproveitamento em percentual, levando em consideração que a vitória vale 3 pontos, o empate vale 1 ponto e a derrota 0 pontos.
#
# Observação: se a quantidade de gols marcados numa partida for maior que a de sofridos, o time venceu. Caso seja igual, o time empatou e se for menor, o time perdeu. Para calcular o aproveitamento devemos fazer a razão entre a pontuação do time pela pontuação máxima que ele poderia receber.

# %%
gols_marcados = [2, 1, 3, 1, 0]
gols_sofridos = [1, 2, 2, 1, 3]

# %%
# o time venceu 2 partidas, empatou 1 e perdeu 2

# 2 * 3 = 6,  1 * 1 = 1, 2 * 0 (soma ponderada)

# pontuação máxima dado que ganhou todas: 15

# razão: 7/15 = 46,66% de aproveitamento

# %%
pontuacao_maxima = len(gols_marcados) * 3

def calcular_pontos(marcados, sofridos):
  vitoria = 0
  empate = 0
  derrota = 0
  pontos = 0
  aprov = 0

  for x, y in zip(marcados, sofridos):
    if x > y:
      vitoria += 1 * 3
    elif x == y :
      empate += 1 * 1
    else:
      derrota
  pontos = vitoria + empate
  aprov = (pontos/pontuacao_maxima) * 100
  return (pontos, aprov)

# %%
pontos, aprov = calcular_pontos(gols_marcados, gols_sofridos)

# %%
print(f"A pontuação do time foi de {pontos} e seu aproveitamento foi de {round(aprov)}%")
# Out:
# A pontuação do time foi de 7 e seu aproveitamento foi de 47%

# %%
# versão do gemini

def calcular_pontos(gols_marcados, gols_sofridos):
  pontos_acumulados = 0
  num_jogos = len(gols_marcados)
  pontuacao_maxima = num_jogos * 3

  for marcados, sofridos in zip(gols_marcados, gols_sofridos):
    if marcados > sofridos:
      pontos_acumulados += 3
    elif marcados == sofridos:
      pontos_acumulados += 1

  aproveitamento = (pontos_acumulados/pontuacao_maxima) * 100

  return pontos_acumulados, aproveitamento

# %%
pontos, aprov = calcular_pontos(gols_marcados, gols_sofridos)

# %%
print(f"A pontuação do time foi de {pontos} e seu aproveitamento foi de {round(aprov)}%")
# Out:
# A pontuação do time foi de 7 e seu aproveitamento foi de 47%

# %%
# solução do professor

gols_marcados = [2, 1, 3, 1, 0]
gols_sofridos = [1, 2, 2, 1, 3]

def calcula_pontos(gols_marcados, gols_sofridos):
  pontos = 0
  for i in range(len(gols_marcados)):
    if gols_marcados[i] > gols_sofridos[i]:
      pontos += 3
    elif gols_marcados[i] == gols_sofridos[i]:
      pontos += 1
  aprov = 100 * pontos / (len(gols_marcados) * 3)
  return (pontos, aprov)

pontos, aprov = calcula_pontos(gols_marcados, gols_sofridos)
print(f"A pontuação do time foi de {pontos} e seu aproveitamento foi de {round(aprov)}%")
# Out:
# A pontuação do time foi de 7 e seu aproveitamento foi de 47%

# %% [markdown]
# Você iniciou um estágio em uma empresa que trabalha com processamento de linguagem natural (NLP). Sua líder requisitou que você criasse um trecho de código que recebe uma frase digitada pela pessoa usuária e filtre apenas as palavras com tamanho maior ou igual a 5, exibindo-as em uma lista. Essa demanda é voltada para a análise do padrão de comportamento de pessoas na escrita de palavras acima dessa quantidade de caracteres.

# %%
# resolução do professor

frase = input("Digite uma frase: ")

frase = frase.replace(',', '').replace('.', '').replace('!', '').replace('?', '').split()

frase_filtrada = list(filter(lambda palavra: len(palavra) >= 5 , frase))

frase_filtrada
# Out:
# Digite uma frase: Aprender Python na Alura é muito bom
# ['Aprender', 'Python', 'Alura', 'muito']

# %%
# minha solução
frase = "Aprender Python na Alura é muito bom"

frase = frase.replace(',', '').replace('.', '').replace('!', '').replace('?', '').split()

frase_filtrada = [palavra for palavra in frase if len(palavra) >= 5 ]

frase_filtrada
# Out:
# ['Aprender', 'Python', 'Alura', 'muito']
